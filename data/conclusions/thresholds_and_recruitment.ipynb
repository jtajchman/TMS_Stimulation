# %%
from recruitment_plotting import plot_threshold_distributions, plot_recruitment_curves
import numpy as np

# %%
exc_monophasic_name = 'L5_TTPC2_cADpyr_Monophasic_run0'
exc_half_sine_name = 'L5_TTPC2_cADpyr_Half-Sine_run0'
exc_biphasic_name = 'L5_TTPC2_cADpyr_Biphasic_run0'
inh_monophasic_name = 'L5_LBC_cNAC_Monophasic_run0'
inh_half_sine_name = 'L5_LBC_cNAC_Half-Sine_run0'
inh_biphasic_name = 'L5_LBC_cNAC_Biphasic_run0'
exc_monophasic_fname = f'data/tms_thresholds/{exc_monophasic_name}/{exc_monophasic_name}_results.json'
exc_half_sine_fname = f'data/tms_thresholds/{exc_half_sine_name}/{exc_half_sine_name}_results.json'
exc_biphasic_fname = f'data/tms_thresholds/{exc_biphasic_name}/{exc_biphasic_name}_results.json'
inh_monophasic_fname = f'data/tms_thresholds/{inh_monophasic_name}/{inh_monophasic_name}_results.json'
inh_half_sine_fname = f'data/tms_thresholds/{inh_half_sine_name}/{inh_half_sine_name}_results.json'
inh_biphasic_fname = f'data/tms_thresholds/{inh_biphasic_name}/{inh_biphasic_name}_results.json'
fname_list = [exc_monophasic_fname, exc_half_sine_fname, exc_biphasic_fname, inh_monophasic_fname, inh_half_sine_fname, inh_biphasic_fname]

# %%
# efields = np.linspace(180, 600, 50)
# efields_list = [efields for fname_list in fname_lists1]
title = "Threshold Distributions (Smoothed)"
legend = ["L5 PC Monophasic", "L5 PC Half-Sine", "L5 PC Biphasic", "L5 LBC Monophasic", "L5 LBC Half-Sine", "L5 LBC Biphasic"]
# xlabel = "Monophasic Recruitment"
# ylabel = "Half-Sine Recruitment"

fig, ax = plot_threshold_distributions(fname_list, 100, 600, 50, legend, title=title, check_prop_sum=True)
# Out:
# L5 PC Monophasic sum = 0.9995650509458366
# L5 PC Half-Sine sum = 1.0
# L5 PC Biphasic sum = 1.0
# L5 LBC Monophasic sum = 0.9929743026439429
# L5 LBC Half-Sine sum = 0.9990586875286327
# L5 LBC Biphasic sum = 1.0

# %%
title = "Recruitment Curves"
plot_recruitment_curves(fname_list, 100, 600, 50, legend, title=title)
# Out:
# (<Figure size 2400x1200 with 1 Axes>,
#  <Axes: title={'center': 'Recruitment Curves'}, xlabel='Electric Field Amplitude (V/m)', ylabel='Recruitment Probability'>)
