# %%
import os
import sys
from pathlib import Path
rootFolder = str(Path(os.path.abspath('')).parent)
sys.path.append(rootFolder)

# %%
from tms_probability.threshold_sim import estimate_cell_threshold, cell_type_threshold_map

# %%
# Monophasic
tms_pulse_width_ms=0.075 # Duration of the positive phase of the pulse
tms_pulse_width_ms *= 4 # Actual pulse width required for input of monophasic pulse (due to monophasic pulse width definition not including trailing negative phase)

pre_tms_period = 0 # For cell to reach baseline/get data on baseline activity
spike_detection_time = 1
tms_spiking_period = tms_pulse_width_ms+spike_detection_time # For spike detection

# Cell type descriptions from the Blue Brain Project glossary: https://bbp.epfl.ch/nmc-portal/glossary.html
# Layer 5 thick-tufted pyramidal cell with an early bifurcating apical tuft - continuous accommodating (adapting) pyramidal cell
cell_name = 'L5_TTPC2_cADpyr'
morphIDs = [1, 2, 3, 4, 5]
angular_resolution = 10 # Angular degrees of separation to use when when determining which field directions to simulate
                        # Applies to both the polar and azimuthal angles

duration = pre_tms_period + tms_spiking_period # ms

starting_E = 100 # Starting point of E-field amplitude in V/m to perform binary search from to estimate the cell's firing threshold at each parameter set
search_factor = 2   # Factor to scale by (up or down) when searching for the bounds to perform the binary search within
                    # Factor should be lower if guess is good to reflect confidence and minimize num of simulations
search_precision = 0.1 # Threshold estimation will be within this distance in V/m from the true, exact value (halving this adds another simulation to all threshold estimations)

num_cores = 8 # Number of cores to allocate to the batch of parallel simulations

tms_params = dict(
    # Coupling params
    decay_rate_percent_per_mm=0,            # Rate of decay that the field diminishes by over space (uniform field at 0)
    E_field_dir={},                         # Empty because it will be populated and iterated over in cell_type_threshold_map
    decay_dir={'Coord_type': 'Spherical',   # Direction over which the field decays (meaningless when decay is 0)
                'Polar': 180,
                'Azimuthal': 0,},
    somatodendritic_axis=[0, 1, 0],         # Defines the direction that Polar=0 points in
    # Waveform params
    stim_type='sTMS',                       # Single-pulse TMS
    stim_start_ms=pre_tms_period,           # When to apply the pulse
    num_pulses_per_burst=1,                 # Number of pulses in a burst (useful for theta burst stimulation)
    tms_pulse_width_ms=tms_pulse_width_ms,
    tms_pulse_shape='Monophasic',
    # Simulation params
    tms_spiking_period=tms_spiking_period,  # Only pass this in for saving at the end
    simulation_duration_ms=duration,
    default_dt = 0.025,                     # Time step when outside of any pulses
    num_time_steps_in_pulse = 50,           # Number of time steps to spend on each pulse (such that pulse_dt = tms_pulse_width / num_time_steps_in_pulse)
    # Plotting quasipotentials
    plot=False,
)

# Synaptic parameters (not fully implemented)
syn_params = None

# Runs the simulations, saves the results in the data folder, and returns the threshold_map data structure
# Takes ~45 minutes to run on 8 cores on my desktop
threshold_map = cell_type_threshold_map(cell_name, morphIDs, starting_E, search_factor, search_precision, angular_resolution, num_cores, tms_params, syn_params)
print(threshold_map)
# Out:
# ---------------------------------------------------------------------------
# RemoteTraceback                           Traceback (most recent call last)
# RemoteTraceback:
# """
# Traceback (most recent call last):
#   File "c:\Users\jacob\anaconda3\Lib\multiprocessing\pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#                     ^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\jacob\anaconda3\Lib\multiprocessing\pool.py", line 51, in starmapstar
#     return list(itertools.starmap(args[0], args[1]))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\jacob\Documents\Work\NetPyNE\TMS_Stimulation\tms_probability\threshold_sim.py", line 14, in estimate_cell_threshold
#     EF_amp# = starting_E
#     ^^^^^^
# UnboundLocalError: cannot access local variable 'EF_amp' where it is not associated with a value
# """
#
# The above exception was the direct cause of the following exception:
#
# UnboundLocalError                         Traceback (most recent call last)
# Cell In[3], line 53
#      49 syn_params = None
#      51 # Runs the simulations, saves the results in the data folder, and returns the threshold_map data structure
#      52 # Takes ~45 minutes to run on 8 cores on my desktop
# ---> 53 threshold_map = cell_type_threshold_map(cell_name, morphIDs, starting_E, search_factor, search_precision, angular_resolution, num_cores, tms_params, syn_params)
#      54 print(threshold_map)
#
# File c:\Users\jacob\Documents\Work\NetPyNE\TMS_Stimulation\tms_probability\threshold_sim.py:90, in cell_type_threshold_map(cell_name, morphIDs, starting_E, search_factor, search_precision, angular_resolution, num_cores, tms_params, syn_params)
#      87             cell_angles_list.append([cell_name_ID, polar, azimuthal])
#      89 with Pool(num_cores) as pool:
# ---> 90     results = pool.starmap(estimate_cell_threshold, params_list)
#      92 for [cell_name_ID, polar, azimuthal], [threshold, num_sim_bounding, num_sim_refining] in zip(cell_angles_list, results):
#      93     threshold_map[cell_name_ID]['Polar'][polar]['Azimuthal'][azimuthal] = {'threshold': threshold,
#      94                                                                             'num_sim_bounding': num_sim_bounding,
#      95                                                                             'num_sim_refining': num_sim_refining,
#      96                                                                             'num_sim_total': num_sim_bounding+num_sim_refining,}
#
# File c:\Users\jacob\anaconda3\Lib\multiprocessing\pool.py:375, in Pool.starmap(self, func, iterable, chunksize)
#     369 def starmap(self, func, iterable, chunksize=None):
#     370     '''
#     371     Like `map()` method but the elements of the `iterable` are expected to
#     372     be iterables as well and will be unpacked as arguments. Hence
#     373     `func` and (a, b) becomes func(a, b).
#     374     '''
# --> 375     return self._map_async(func, iterable, starmapstar, chunksize).get()
#
# File c:\Users\jacob\anaconda3\Lib\multiprocessing\pool.py:774, in ApplyResult.get(self, timeout)
#     772     return self._value
#     773 else:
# --> 774     raise self._value
#
# UnboundLocalError: cannot access local variable 'EF_amp' where it is not associated with a value

# %%
# Half-Sine
tms_pulse_width_ms=0.075 # Duration of the positive phase of the pulse
tms_pulse_width_ms *= 2 # Actual pulse width required for input of biphasic pulse (due to biphasic pulse width definition not including second negative phase)

pre_tms_period = 0 # For cell to reach baseline/get data on baseline activity
spike_detection_time = 1
tms_spiking_period = tms_pulse_width_ms+spike_detection_time # For spike detection

# Layer 5 thick-tufted pyramidal cell 2 - continuous accommodating (adapting) pyramidal cell
cell_name = 'L5_TTPC2_cADpyr'
morphIDs = [1, 2, 3, 4, 5]
angular_resolution = 10 # Angular degrees of separation to use when when determining which field directions to simulate
                        # Applies to both the polar and azimuthal angles

duration = pre_tms_period + tms_spiking_period # ms

starting_E = 100 # Starting point of E-field amplitude in V/m to perform binary search from to estimate the cell's firing threshold at each parameter set
search_factor = 2   # Factor to scale by (up or down) when searching for the bounds to perform the binary search within
                    # Factor should be lower if guess is good to reflect confidence and minimize num of simulations
search_precision = 0.1 # Threshold estimation will be within this distance in V/m from the true, exact value (halving this adds another simulation to all threshold estimations)

num_cores = 8 # Number of cores to allocate to the batch of parallel simulations

tms_params = dict(
    # Coupling params
    decay_rate_percent_per_mm=0,            # Rate of decay that the field diminishes by over space (uniform field at 0)
    E_field_dir={},                         # Empty because it will be populated and iterated over in cell_type_threshold_map
    decay_dir={'Coord_type': 'Spherical',   # Direction over which the field decays (meaningless when decay is 0)
                'Polar': 180,
                'Azimuthal': 0,},
    somatodendritic_axis=[0, 1, 0],         # Defines the direction that Polar=0 points in
    # Waveform params
    stim_type='sTMS',                       # Single-pulse TMS
    stim_start_ms=pre_tms_period,           # When to apply the pulse
    num_pulses_per_burst=1,                 # Number of pulses in a burst (useful for theta burst stimulation)
    tms_pulse_width_ms=tms_pulse_width_ms,
    tms_pulse_shape='Half-Sine',
    # Simulation params
    tms_spiking_period=tms_spiking_period,  # Only pass this in for saving at the end
    simulation_duration_ms=duration,
    default_dt = 0.025,                     # Time step when outside of any pulses
    num_time_steps_in_pulse = 50,           # Number of time steps to spend on each pulse (such that pulse_dt = tms_pulse_width / num_time_steps_in_pulse)
    # Plotting quasipotentials
    plot=False,
)

# Synaptic parameters (not fully implemented)
syn_params = None

# Runs the simulations, saves the results in the data folder, and returns the threshold_map data structure
# Takes ~45 minutes to run on 8 cores on my desktop
threshold_map = cell_type_threshold_map(cell_name, morphIDs, starting_E, search_factor, search_precision, angular_resolution, num_cores, tms_params, syn_params)
print(threshold_map)
# Out:
# [('L5_LBC_cNAC_1', 100, 2, 0.1, {'decay_rate_percent_per_mm': 0, 'E_field_dir': {'Coord_type': 'Spherical', 'Polar': 0.0, 'Azimuthal': 0.0}, 'decay_dir': {'Coord_type': 'Spherical', 'Polar': 180, 'Azimuthal': 0}, 'somatodendritic_axis': [0, 1, 0], 'stim_type': 'sTMS', 'stim_start_ms': 0, 'num_pulses_per_burst': 1, 'tms_pulse_width_ms': 0.15, 'tms_pulse_shape': 'Half-Sine', 'tms_spiking_period': 1.15, 'simulation_duration_ms': 1.15, 'default_dt': 0.025, 'num_time_steps_in_pulse': 50, 'plot': False}, {'rate': 1, 'weight': 0}), ('L5_LBC_cNAC_1', 100, 2, 0.1, {'decay_rate_percent_per_mm': 0, 'E_field_dir': {'Coord_type': 'Spherical', 'Polar': 10.0, 'Azimuthal': 0.0}, 'decay_dir': {'Coord_type': 'Spherical', 'Polar': 180, 'Azimuthal': 0}, 'somatodendritic_axis': [0, 1, 0], 'stim_type': 'sTMS', 'stim_start_ms': 0, 'num_pulses_per_burst': 1, 'tms_pulse_width_ms': 0.15, 'tms_pulse_shape': 'Half-Sine', 'tms_spiking_period': 1.15, 'simulation_duration_ms': 1.15, 'default_dt': 0.025, 'num_time_steps_in_pulse': 50, 'plot': False}, {'rate': 1, 'weight': 0}), ('L5_LBC_cNAC_1', 100, 2, 0.1, {'decay_rate_percent_per_mm': 0, 'E_field_dir': {'Coord_type': 'Spherical', 'Polar': 10.0, 'Azimuthal': 51.42857142857143}, 'decay_dir': {'Coord_type': 'Spherical', 'Polar': 180, 'Azimuthal': 0}, 'somatodendritic_axis': [0, 1, 0], 'stim_type': 'sTMS', 'stim_start_ms': 0, 'num_pulses_per_burst': 1, 'tms_pulse_width_ms': 0.15, 'tms_pulse_shape': 'Half-Sine', 'tms_spiking_period': 1.15, 'simulation_duration_ms': 1.15, 'default_dt': 0.025, 'num_time_steps_in_pulse': 50, 'plot': False}, {'rate': 1, 'weight': 0}), ('L5_LBC_cNAC_1', 100, 2, 0.1, {'decay_rate_percent_per_mm': 0, 'E_field_dir': {'Coord_type': 'Spherical', 'Polar': 10.0, 'Azimuthal': 102.85714285714286}, 'decay_dir': {'Coord_type': 'Spherical', 'Polar': 180, 'Azimuthal': 0}, 'somatodendritic_axis': [0, 1, 0], 'stim_type': 'sTMS', 'stim_start_ms': 0, 'num_pulses_per_burst': 1, 'tms_pulse_width_ms': 0.15, 'tms_pulse_shape': 'Half-Sine', 'tms_spiking_period': 1.15, 'simulation_duration_ms': 1.15, 'default_dt': 0.025, 'num_time_steps_in_pulse': 50, 'plot': False}, {'rate': 1, 'weight': 0}), ('L5_LBC_cNAC_1', 100, 2, 0.1, {'decay_rate_percent_per_mm': 0, 'E_field_dir': {'Coord_type': 'Spherical', 'Polar': 10.0, 'Azimuthal': 154.28571428571428}, 'decay_dir': {'Coord_type': 'Spherical', 'Polar': 180, 'Azimuthal': 0}, 'somatodendritic_axis': [0, 1, 0], 'stim_type': 'sTMS', 'stim_start_ms': 0, 'num_pulses_per_burst': 1, 'tms_pulse_width_ms': 0.15, 'tms_pulse_shape': 'Half-Sine', 'tms_spiking_period': 1.15, 'simulation_duration_ms': 1.15, 'default_dt': 0.025, 'num_time_steps_in_pulse': 50, 'plot': False}, {'rate': 1, 'weight': 0}), ('L5_LBC_cNAC_1', 100, 2, 0.1, {'decay_rate_percent_per_mm': 0, 'E_field_dir': {'Coord_type': 'Spherical', 'Polar': 10.0, 'Azimuthal': 205.71428571428572}, 'decay_dir': {'Coord_type': 'Spherical', 'Polar': 180, 'Azimuthal': 0}, 'somatodendritic_axis': [0, 1, 0], 'stim_type': 'sTMS', 'stim_start_ms': 0, 'num_pulses_per_burst': 1, 'tms_pulse_width_ms': 0.15, 'tms_pulse_shape': 'Half-Sine', 'tms_spiking_period': 1.15, 'simulation_duration_ms': 1.15, 'default_dt': 0.025, 'num_time_steps_in_pulse': 50, 'plot': False}, {'rate': 1, 'weight': 0}), ('L5_LBC_cNAC_1', 100, 2, 0.1, {'decay_rate_percent_per_mm': 0, 'E_field_dir': {'Coord_type': 'Spherical', 'Polar': 10.0, 'Azimuthal': 257.14285714285717}, 'decay_dir': {'Coord_type': 'Spherical', 'Polar': 180, 'Azimuthal': 0}, 'somatodendritic_axis': [0, 1, 0], 'stim_type': 'sTMS', 'stim_start_ms': 0, 'num_pulses_per_burst': 1, 'tms_pulse_width_ms': 0.15, 'tms_pulse_shape': 'Half-Sine', 'tms_spiking_period': 1.15, 'simulation_duration_ms': 1.15, 'default_dt': 0.025, 'num_time_steps_in_pulse': 50, 'plot': False}, {'rate': 1, 'weight': 0}), ('L5_LBC_cNAC_1', 100, 2, 0.1, {'decay_rate_percent_per_mm': 0, 'E_field_dir': {'Coord_type': 'Spherical', 'Polar': 10.0, 'Azimuthal': 308.57142857142856}, 'decay_dir': {'Coord_type': 'Spherical', 'Polar': 180 ...
# [(292.67578125, 3, 10), (312.20703125, 3, 10), (301.46484375, 3, 10), (310.25390625, 3, 10), (292.87109375, 3, 10), (277.05078125, 3, 10), (276.46484375, 3, 10), (290.91796875, 3, 10), (311.81640625, 3, 10), (293.65234375, 3, 10), (287.40234375, 3, 10), (293.06640625, 3, 10), (315.13671875, 3, 10), (315.91796875, 3, 10), (292.28515625, 3, 10), (275.48828125, 3, 10), (267.08984375, 3, 10), (267.67578125, 3, 10), (277.24609375, 3, 10), (294.82421875, 3, 10), (319.23828125, 3, 10), (318.65234375, 3, 10), (297.36328125, 3, 10), (285.64453125, 3, 10), (282.91015625, 3, 10), (294.04296875, 3, 10), (308.88671875, 3, 10), (329.19921875, 3, 10), (332.91015625, 3, 10), (295.99609375, 3, 10), (277.83203125, 3, 10), (270.21484375, 3, 10), (267.67578125, 3, 10), (266.50390625, 3, 10), (272.16796875, 3, 10), (285.05859375, 3, 10), (304.58984375, 3, 10), (331.54296875, 3, 10), (345.80078125, 3, 10), (317.48046875, 3, 10), (312.20703125, 3, 10), (296.77734375, 3, 10), (288.57421875, 3, 10), (287.59765625, 3, 10), (296.97265625, 3, 10), (308.49609375, 3, 10), (323.33984375, 3, 10), (350.68359375, 3, 10), (342.87109375, 3, 10), (310.05859375, 3, 10), (283.88671875, 3, 10), (264.94140625, 3, 10), (256.34765625, 3, 10), (256.93359375, 3, 10), (267.28515625, 3, 10), (274.90234375, 3, 10), (279.78515625, 3, 10), (290.33203125, 3, 10), (306.93359375, 3, 10), (329.58984375, 3, 10), (358.88671875, 3, 10), (353.22265625, 3, 10), (330.37109375, 3, 10), (296.38671875, 3, 10), (305.95703125, 3, 10), (317.67578125, 3, 10), (305.76171875, 3, 10), (299.12109375, 3, 10), (298.53515625, 3, 10), (306.93359375, 3, 10), (325.68359375, 3, 10), (344.43359375, 3, 10), (373.14453125, 3, 10), (361.42578125, 3, 10), (344.43359375, 3, 10), (303.41796875, 3, 10), (278.22265625, 3, 10), (259.66796875, 3, 10), (250.09765625, 3, 10), (248.73046875, 3, 10), (255.17578125, 3, 10), (270.60546875, 3, 10), (290.13671875, 3, 10), (299.31640625, 3, 10), (313.96484375, 3, 10), (333.30078125, 3, 10), (332.71484375, 3, 10), (328.22265625, 3, 10), (337.79296875, 3, 10), (314.74609375, 3, 10), (299.12109375, 3, 10), (284.27734375, 3, 10), (287.98828125, 3, 10), (305.37109375, 3, 10), (318.06640625, 3, 10), (302.24609375, 3, 10), (296.19140625, 3, 10), (297.94921875, 3, 10), (308.10546875, 3, 10), (328.41796875, 3, 10), (361.03515625, 3, 10), (369.04296875, 3, 10), (364.55078125, 3, 10), (372.55859375, 3, 10), (349.12109375, 3, 10), (304.98046875, 3, 10), (279.39453125, 3, 10), (261.42578125, 3, 10), (251.07421875, 3, 10), (247.94921875, 3, 10), (251.85546875, 3, 10), (262.98828125, 3, 10), (283.10546875, 3, 10), (311.62109375, 3, 10), (325.68359375, 3, 10), (343.06640625, 3, 10), (315.33203125, 3, 10), (294.43359375, 3, 10), (286.81640625, 3, 10), (290.72265625, 3, 10), (306.93359375, 3, 10), (297.75390625, 3, 10), (286.03515625, 3, 10), (276.66015625, 3, 10), (284.08203125, 3, 10), (296.19140625, 3, 10), (320.01953125, 3, 10), (313.57421875, 3, 10), (303.80859375, 3, 10), (302.83203125, 3, 10), (310.83984375, 3, 10), (327.63671875, 3, 10), (355.37109375, 3, 10), (329.78515625, 3, 10), (317.08984375, 3, 10), (316.89453125, 3, 10), (329.00390625, 3, 10), (350.48828125, 3, 10), (306.73828125, 3, 10), (281.34765625, 3, 10), (264.35546875, 3, 10), (254.58984375, 3, 10), (251.46484375, 3, 10), (257.32421875, 3, 10), (267.67578125, 3, 10), (286.81640625, 3, 10), (317.87109375, 3, 10), (359.27734375, 3, 10), (347.55859375, 3, 10), (303.80859375, 3, 10), (278.22265625, 3, 10), (265.13671875, 3, 10), (261.81640625, 3, 10), (267.87109375, 3, 10), (284.08203125, 3, 10), (288.37890625, 3, 10), (278.02734375, 3, 10), (277.44140625, 3, 10), (282.51953125, 3, 10), (295.21484375, 3, 10), (308.69140625, 3, 10), (310.05859375, 3, 10), (321.38671875, 3, 10), (319.43359375, 3, 10), (324.31640625, 3, 10), (338.37890625, 3, 10), (363.76953125, 3, 10), (362.59765625, 3, 10), (334.86328125, 3, 10), (317.28515625, 3, 10), (307.91015625, 3, 10), (306.54296875, 3, 10), (322.94921875, 3, 10), (309.86328125, 3, 10 ...
# {'L5_LBC_cNAC_1': {'Polar': {0.0: {'Azimuthal': {0.0: {'threshold': 292.67578125, 'num_sim_bounding': 3, 'num_sim_refining': 10, 'num_sim_total': 13}}}, 10.0: {'Azimuthal': {0.0: {'threshold': 312.20703125, 'num_sim_bounding': 3, 'num_sim_refining': 10, 'num_sim_total': 13}, 51.42857142857143: {'threshold': 301.46484375, 'num_sim_bounding': 3, 'num_sim_refining': 10, 'num_sim_total': 13}, 102.85714285714286: {'threshold': 310.25390625, 'num_sim_bounding': 3, 'num_sim_refining': 10, 'num_sim_total': 13}, 154.28571428571428: {'threshold': 292.87109375, 'num_sim_bounding': 3, 'num_sim_refining': 10, 'num_sim_total': 13}, 205.71428571428572: {'threshold': 277.05078125, 'num_sim_bounding': 3, 'num_sim_refining': 10, 'num_sim_total': 13}, 257.14285714285717: {'threshold': 276.46484375, 'num_sim_bounding': 3, 'num_sim_refining': 10, 'num_sim_total': 13}, 308.57142857142856: {'threshold': 290.91796875, 'num_sim_bounding': 3, 'num_sim_refining': 10, 'num_sim_total': 13}}}, 20.0: {'Azimuthal': {0.0: {'threshold': 311.81640625, 'num_sim_bounding': 3, 'num_sim_refining': 10, 'num_sim_total': 13}, 27.692307692307693: {'threshold': 293.65234375, 'num_sim_bounding': 3, 'num_sim_refining': 10, 'num_sim_total': 13}, 55.38461538461539: {'threshold': 287.40234375, 'num_sim_bounding': 3, 'num_sim_refining': 10, 'num_sim_total': 13}, 83.07692307692308: {'threshold': 293.06640625, 'num_sim_bounding': 3, 'num_sim_refining': 10, 'num_sim_total': 13}, 110.76923076923077: {'threshold': 315.13671875, 'num_sim_bounding': 3, 'num_sim_refining': 10, 'num_sim_total': 13}, 138.46153846153845: {'threshold': 315.91796875, 'num_sim_bounding': 3, 'num_sim_refining': 10, 'num_sim_total': 13}, 166.15384615384616: {'threshold': 292.28515625, 'num_sim_bounding': 3, 'num_sim_refining': 10, 'num_sim_total': 13}, 193.84615384615387: {'threshold': 275.48828125, 'num_sim_bounding': 3, 'num_sim_refining': 10, 'num_sim_total': 13}, 221.53846153846155: {'threshold': 267.08984375, 'num_sim_bounding': 3, 'num_sim_refining': 10, 'num_sim_total': 13}, 249.23076923076923: {'threshold': 267.67578125, 'num_sim_bounding': 3, 'num_sim_refining': 10, 'num_sim_total': 13}, 276.9230769230769: {'threshold': 277.24609375, 'num_sim_bounding': 3, 'num_sim_refining': 10, 'num_sim_total': 13}, 304.61538461538464: {'threshold': 294.82421875, 'num_sim_bounding': 3, 'num_sim_refining': 10, 'num_sim_total': 13}, 332.3076923076923: {'threshold': 319.23828125, 'num_sim_bounding': 3, 'num_sim_refining': 10, 'num_sim_total': 13}}}, 30.0: {'Azimuthal': {0.0: {'threshold': 318.65234375, 'num_sim_bounding': 3, 'num_sim_refining': 10, 'num_sim_total': 13}, 20.0: {'threshold': 297.36328125, 'num_sim_bounding': 3, 'num_sim_refining': 10, 'num_sim_total': 13}, 40.0: {'threshold': 285.64453125, 'num_sim_bounding': 3, 'num_sim_refining': 10, 'num_sim_total': 13}, 60.0: {'threshold': 282.91015625, 'num_sim_bounding': 3, 'num_sim_refining': 10, 'num_sim_total': 13}, 80.0: {'threshold': 294.04296875, 'num_sim_bounding': 3, 'num_sim_refining': 10, 'num_sim_total': 13}, 100.0: {'threshold': 308.88671875, 'num_sim_bounding': 3, 'num_sim_refining': 10, 'num_sim_total': 13}, 120.0: {'threshold': 329.19921875, 'num_sim_bounding': 3, 'num_sim_refining': 10, 'num_sim_total': 13}, 140.0: {'threshold': 332.91015625, 'num_sim_bounding': 3, 'num_sim_refining': 10, 'num_sim_total': 13}, 160.0: {'threshold': 295.99609375, 'num_sim_bounding': 3, 'num_sim_refining': 10, 'num_sim_total': 13}, 180.0: {'threshold': 277.83203125, 'num_sim_bounding': 3, 'num_sim_refining': 10, 'num_sim_total': 13}, 200.0: {'threshold': 270.21484375, 'num_sim_bounding': 3, 'num_sim_refining': 10, 'num_sim_total': 13}, 220.0: {'threshold': 267.67578125, 'num_sim_bounding': 3, 'num_sim_refining': 10, 'num_sim_total': 13}, 240.0: {'threshold': 266.50390625, 'num_sim_bounding': 3, 'num_sim_refining': 10, 'num_sim_total': 13}, 260.0: {'threshold': 272.16796875, 'num_sim_bounding': 3, 'num_sim_refining': 10, 'num_sim_total': 13}, 280.0: {'threshold': 285. ...
