# %%
import os
import sys
from pathlib import Path
rootFolder = str(Path(os.path.abspath('')).parent)
sys.path.append(rootFolder)
os.chdir(rootFolder)

# %%
from tms_probability.plotting import plot_threshold_heatmap_by_cell, plot_threshold_diff_heatmap_by_cell, plot_threshold_heatmap_by_cell_test
# %matplotlib inline

exc_monophasic_name = 'L5_TTPC2_cADpyr_monophasic'
exc_half_sine_name = 'L5_TTPC2_cADpyr_half_sine'
inh_monophasic_name = 'L5_LBC_cNAC_monophasic'
inh_half_sine_name = 'L5_LBC_cNAC_half_sine'
exc_monophasic_fname = f'data/tms_thresholds/{exc_monophasic_name}/{exc_monophasic_name}_results.json'
exc_half_sine_fname = f'data/tms_thresholds/{exc_half_sine_name}/{exc_half_sine_name}_results.json'
inh_monophasic_fname = f'data/tms_thresholds/{inh_monophasic_name}/{inh_monophasic_name}_results.json'
inh_half_sine_fname = f'data/tms_thresholds/{inh_half_sine_name}/{inh_half_sine_name}_results.json'
fname_list = [exc_monophasic_fname, exc_half_sine_fname, inh_monophasic_fname, inh_half_sine_fname]

# for fname in fname_list:
#     plot_threshold_heatmap_by_cell_test(fname)
plot_threshold_heatmap_by_cell_test(exc_monophasic_fname)

# %%
from tms_probability.plotting import plot_threshold_heatmap_by_cell, plot_threshold_diff_heatmap_by_cell
# %matplotlib inline

exc_monophasic_name = 'L5_TTPC2_cADpyr_monophasic'
exc_half_sine_name = 'L5_TTPC2_cADpyr_half_sine'
inh_monophasic_name = 'L5_LBC_cNAC_monophasic'
inh_half_sine_name = 'L5_LBC_cNAC_half_sine'
exc_monophasic_fname = f'data/tms_thresholds/{exc_monophasic_name}/{exc_monophasic_name}_results.json'
exc_half_sine_fname = f'data/tms_thresholds/{exc_half_sine_name}/{exc_half_sine_name}_results.json'
inh_monophasic_fname = f'data/tms_thresholds/{inh_monophasic_name}/{inh_monophasic_name}_results.json'
inh_half_sine_fname = f'data/tms_thresholds/{inh_half_sine_name}/{inh_half_sine_name}_results.json'
exc_fnames = [exc_monophasic_fname, exc_half_sine_fname]#, inh_monophasic_fname, inh_half_sine_fname]
plot_threshold_diff_heatmap_by_cell(exc_fnames)

inh_fnames = [inh_monophasic_fname, inh_half_sine_fname]
plot_threshold_diff_heatmap_by_cell(inh_fnames)
