# %%
from plot_cell_with_thresholds import overlay_cell_and_thresholds
# from extracellular_stim_tools.spherical_cartesian_conversion import norm_cartesian_to_spherical, norm_spherical_to_cartesian
import matplotlib.pyplot as plt
# %matplotlib widget

# %%
cell_name = 'L5_TTPC2_cADpyr_1'
# cell_id = 3
# cell_name = f'L5_LBC_cNAC_{cell_id}'
exc_monophasic_name='L5_TTPC2_cADpyr_monophasic' # (120.0, 236.25)
# exc_monophasic_name='L5_TTPC2_cADpyr_run8' # (60.0, 123.75)
# exc_monophasic_name='L5_LBC_cNAC_monophasic'
threshold_fname = f'data/tms_thresholds/{exc_monophasic_name}/{exc_monophasic_name}_results.json'
sim_direction = overlay_cell_and_thresholds(threshold_fname, cell_name, radius=1000, condition='Monophasic', init_site_direction='lowest_threshold')
print(sim_direction)
# compartCell_L5_TTPC2_cADpyr_1_HH_full_0.Node_130
# [-414.09567287 -758.75549338  855.68725627]
# [-360.76110866 -784.94433615  829.30767864]
# [-411.6195071  -807.81738303  899.98553508]
# [-402.11224392 -804.24865744  904.61273235]
# [-370.75634792 -794.53723166  890.85528606]
# Out:
# compartCell_L5_TTPC2_cADpyr_1_HH_full_0.Myelin_131
# [[-350.83001108 -753.82723307  855.11229856]
#  [-357.96310891 -760.27408459  868.18152479]
#  [-366.12865222 -768.85870734  879.1819451 ]
#  [-375.24561481 -776.18887841  890.3770493 ]
#  [-382.40542494 -783.97797239  902.63955605]]
# [array([-350.83001108, -357.96310891, -366.12865222, -375.24561481,
#        -382.40542494]), array([-855.11229856, -868.18152479, -879.1819451 , -890.3770493 ,
#        -902.63955605]), array([-753.82723307, -760.27408459, -768.85870734, -776.18887841,
#        -783.97797239])]
# (120.0, 236.25)
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# cell_name = 'L5_TTPC2_cADpyr_1'
cell_name = f'L5_LBC_cNAC_{cell_id}'
# exc_monophasic_name='L5_TTPC2_cADpyr_monophasic'
# exc_half_sine_name='L5_TTPC2_cADpyr_half_sine'
# exc_monophasic_name='L5_TTPC2_cADpyr_run7'
# exc_half_sine_name='L5_TTPC2_cADpyr_run8'
exc_monophasic_name='L5_LBC_cNAC_monophasic'
exc_half_sine_name='L5_LBC_cNAC_half_sine'
threshold_fnames = [f'data/tms_thresholds/{exc_monophasic_name}/{exc_monophasic_name}_results.json',
                   f'data/tms_thresholds/{exc_half_sine_name}/{exc_half_sine_name}_results.json']
conditions = ['Monophasic', 'Half-Sine']
overlay_cell_and_thresholds(threshold_fnames, cell_name, radius=1000, condition=conditions)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 2
#       1 # cell_name = 'L5_TTPC2_cADpyr_1'
# ----> 2 cell_name = f'L5_LBC_cNAC_{cell_id}'
#       3 # exc_monophasic_name='L5_TTPC2_cADpyr_monophasic'
#       4 # exc_half_sine_name='L5_TTPC2_cADpyr_half_sine'
#       5 # exc_monophasic_name='L5_TTPC2_cADpyr_run7'
#       6 # exc_half_sine_name='L5_TTPC2_cADpyr_run8'
#       7 exc_monophasic_name='L5_LBC_cNAC_monophasic'
#
# NameError: name 'cell_id' is not defined
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
