# %%
# %matplotlib ipympl
import os
import sys
from pathlib import Path

rootFolder = str(Path(os.path.abspath('')).parent)
sys.path.append(rootFolder)

from tms_tools.tms_efield import get_efield
import matplotlib

#matplotlib.use('Agg')

wav, time = get_efield(
    freq_Hz = 20.,
    duration_ms = 300.,
    pulse_resolution_ms = 1.,
    tstart_ms = 0.,
    ef_amp_V_per_m = 100.,
    pshape = "Sine",
    width_ms = 25.,
    pat = None,
    npulses = 2,
    interval_ms = 0.,
    p_onset_interval_ms = None,
    set_freq_Hz = None,
    plot = True,
    interp = True,
)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
