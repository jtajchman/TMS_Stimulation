# %%
from tms_probability.threshold_sim import estimate_cell_threshold, cell_type_threshold_map

# %%
tms_pulse_width_ms=0.1                      #

pre_tms_period = 0 # For cell to reach baseline/get data on baseline activity
spike_detection_time = 1
tms_spiking_period = tms_pulse_width_ms+spike_detection_time # For spike detection
post_tms_period = 0 # For more baseline recording if necessary

cell_name = 'L23_PC_cADpyr'
# L23_PC_cADpyr, L5_TTPC2_cADpyr, L23_SBC_bNAC, L5_LBC_cNAC
# TODO: Look at Jones 2007 paper to find cell types?
morphIDs = [1, 2, 3, 4, 5]
angular_resolution = 30

duration = pre_tms_period + tms_spiking_period + post_tms_period # ms

starting_E = 100
search_factor = 2 # Should essentially be a reflection of confidence that starting_E is a good guess: factor should be lower if guess is good
search_precision = 0.1 # Threshold estimation will be within this distance from the true, exact value

num_cores = 4

tms_params = dict(
    # Coupling params
    decay_rate_percent_per_mm=0,            #
    E_field_dir={},
    decay_dir={'Coord_type': 'Spherical',
                'Polar': 180,
                'Azimuthal': 0,},
    somatodendritic_axis=[0, 1, 0],
    # Waveform params
    stim_type='sTMS',
    stim_start_ms=pre_tms_period,
    num_pulses_per_burst=1,
    tms_pulse_width_ms=tms_pulse_width_ms,  #
    tms_pulse_shape='Ideal_Sine',           #
    # Simulation params
    tms_spiking_period=tms_spiking_period,
    simulation_duration_ms=duration,
    default_dt = 0.025,
    num_time_steps_in_pulse = 50,
    # Plotting quasipotentials
    plot=False,
)

syn_params = dict(
    rate=1,
    weight=0,
)

threshold_map = cell_type_threshold_map(cell_name, morphIDs, starting_E, search_factor, search_precision, angular_resolution, num_cores, tms_params, syn_params)
print(threshold_map)
# [(65.33203125, 2, 8), (65.33203125, 2, 8), (65.33203125, 2, 8), (65.33203125, 2, 8), (65.33203125, 2, 8), (65.33203125, 2, 8), (65.33203125, 2, 8), (65.33203125, 2, 8), (65.33203125, 2, 8), (65.33203125, 2, 8), (65.33203125, 2, 8), (65.33203125, 2, 8), (65.33203125, 2, 8), (65.33203125, 2, 8), (65.33203125, 2, 8), (65.33203125, 2, 8), (65.33203125, 2, 8), (65.33203125, 2, 8), (65.33203125, 2, 8), (65.33203125, 2, 8), (65.33203125, 2, 8), (65.33203125, 2, 8), (65.33203125, 2, 8), (65.33203125, 2, 8), (65.33203125, 2, 8), (65.33203125, 2, 8), (65.33203125, 2, 8), (65.33203125, 2, 8), (65.33203125, 2, 8), (65.33203125, 2, 8), (65.33203125, 2, 8), (65.33203125, 2, 8), (65.33203125, 2, 8), (65.33203125, 2, 8), (65.33203125, 2, 8), (65.33203125, 2, 8), (65.33203125, 2, 8), (65.33203125, 2, 8), (65.33203125, 2, 8), (65.33203125, 2, 8), (65.33203125, 2, 8), (65.33203125, 2, 8), (65.33203125, 2, 8), (65.33203125, 2, 8), (65.33203125, 2, 8), (65.33203125, 2, 8), (65.33203125, 2, 8), (65.33203125, 2, 8), (71.77734375, 2, 8), (71.77734375, 2, 8), (71.77734375, 2, 8), (71.77734375, 2, 8), (71.77734375, 2, 8), (71.77734375, 2, 8), (71.77734375, 2, 8), (71.77734375, 2, 8), (71.77734375, 2, 8), (71.77734375, 2, 8), (71.77734375, 2, 8), (71.77734375, 2, 8), (71.77734375, 2, 8), (71.77734375, 2, 8), (71.77734375, 2, 8), (71.77734375, 2, 8), (71.77734375, 2, 8), (71.77734375, 2, 8), (71.77734375, 2, 8), (71.77734375, 2, 8), (71.77734375, 2, 8), (71.77734375, 2, 8), (71.77734375, 2, 8), (71.77734375,
), (83.30078125, 2, 8), (83.30078125, 2, 8), (83.30078125, 2, 8), (83.30078125, 2, 8), (83.30078125, 2, 8), (83.30078125, 2, 8), (83.30078125, 2, 8), (83.30078125, 2, 8), (83.30078125, 2, 8), (83.30078125, 2, 8), (83.30078125, 2, 8), (83.30078125, 2, 8), (83.30078125, 2, 8), (83.30078125, 2, 8), (83.30078125, 2, 8), (83.30078125, 2, 8), (83.30078125, 2, 8), (83.30078125, 2, 8), (83.30078125, 2, 8), (83.30078125, 2, 8), (83.30078125, 2, 8), (83.30078125, 2, 8), (83.30078125, 2, 8), (83.30078125, 2, 8), (83.30078125, 2, 8), (83.30078125, 2, 8), (83.30078125, 2, 8), (83.30078125, 2, 8), (83.30078125, 2, 8), (83.30078125, 2, 8), (83.30078125, 2, 8), (83.30078125, 2, 8), (83.30078125, 2, 8)]
#
# Out:
# [('L23_PC_cADpyr_1', 100, 2, 0.1, {'decay_rate_percent_per_mm': 0, 'E_field_dir': {'Coord_type': 'Spherical', 'Polar': 0.0, 'Azimuthal': 0.0}, 'decay_dir': {'Coord_type': 'Spherical', 'Polar': 180, 'Azimuthal': 0}, 'somatodendritic_axis': [0, 1, 0], 'stim_type': 'sTMS', 'stim_start_ms': 0, 'num_pulses_per_burst': 1, 'tms_pulse_width_ms': 0.1, 'tms_pulse_shape': 'Ideal_Sine', 'tms_spiking_period': 1.1, 'simulation_duration_ms': 1.1, 'default_dt': 0.025, 'num_time_steps_in_pulse': 50, 'plot': False}, {'rate': 1, 'weight': 0}), ('L23_PC_cADpyr_1', 100, 2, 0.1, {'decay_rate_percent_per_mm': 0, 'E_field_dir': {'Coord_type': 'Spherical', 'Polar': 30.0, 'Azimuthal': 0.0}, 'decay_dir': {'Coord_type': 'Spherical', 'Polar': 180, 'Azimuthal': 0}, 'somatodendritic_axis': [0, 1, 0], 'stim_type': 'sTMS', 'stim_start_ms': 0, 'num_pulses_per_burst': 1, 'tms_pulse_width_ms': 0.1, 'tms_pulse_shape': 'Ideal_Sine', 'tms_spiking_period': 1.1, 'simulation_duration_ms': 1.1, 'default_dt': 0.025, 'num_time_
# ...

# %%
from tms_probability.probability_analysis import thresholds_to_probability_from_file

fname = 'L23_PC_cADpyr_3'
print(thresholds_to_probability_from_file(f'C:/Users/jacob/Documents/Work/NetPyNE/TMS_Stimulation/data/tms_thresholds/{fname}/{fname}_results.json', 60))
fname = 'L23_PC_cADpyr_4'
print(thresholds_to_probability_from_file(f'C:/Users/jacob/Documents/Work/NetPyNE/TMS_Stimulation/data/tms_thresholds/{fname}/{fname}_results.json', 60))
fname = 'L23_PC_cADpyr_8'
print(thresholds_to_probability_from_file(f'C:/Users/jacob/Documents/Work/NetPyNE/TMS_Stimulation/data/tms_thresholds/{fname}/{fname}_results.json', 60))
# Out:
# [[0.0, 0.4, 5], [30.0, 0.36666666666666664, 30], [60.0, 0.2909090909090909, 55], [90.0, 0.13333333333333333, 60], [120.0, 0.12727272727272726, 55], [150.0, 0.1, 30], [180.0, 0.0, 5]]
# [[0.0, 0.4, 5], [30.0, 0.4, 30], [60.0, 0.2909090909090909, 55], [90.0, 0.16666666666666666, 60], [120.0, 0.16363636363636364, 55], [150.0, 0.13333333333333333, 30], [180.0, 0.0, 5]]
# [[0.0, 0.4, 5], [30.0, 0.4, 30], [60.0, 0.2909090909090909, 55], [90.0, 0.16666666666666666, 60], [120.0, 0.16363636363636364, 55], [150.0, 0.13333333333333333, 30], [180.0, 0.0, 5]]
